# %%
import pandas as pd

df = pd.read_csv('../data/raw/dados.csv')
df.head()
# Out:
#    idade  renda  score  target
# 0     25   2000    300       0
# 1     35   5000    700       1
# 2     45   7000    800       1
# 3     23   1800    200       0
# 4     40   6500    750       1
